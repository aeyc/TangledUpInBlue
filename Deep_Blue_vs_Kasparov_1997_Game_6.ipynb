# %% [markdown]
# **Basic Introduction about Chess**
#
# Chess is a game which has characterstics as:
# * The rules of the game are known in advance
# * Players are assumed to be rational

# %%
import chess
board = chess.Board()

# %%
#1
board.push_san("e4") #Deep Blue
board.push_san("c6") #Kasparov
board
# Out:
# Board('rnbqkbnr/pp1ppppp/2p5/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2')

# %%
#2
board.push_san("d4") #Deep Blue
board.push_san("d5") #Kasparov
board
# Out:
# Board('rnbqkbnr/pp2pppp/2p5/3p4/3PP3/8/PPP2PPP/RNBQKBNR w KQkq - 0 3')

# %%
#3 
board.push_san("Nc3") #Deep Blue
board.push_san("dxe4") #Kasparov
board
# Out:
# Board('rnbqkbnr/pp2pppp/2p5/8/3Pp3/2N5/PPP2PPP/R1BQKBNR w KQkq - 0 4')

# %%
#4
board.push_san("Nxe4") #Deep Blue
board.push_san("Nd7") #Kasparov
board
# Out:
# Board('r1bqkbnr/pp1npppp/2p5/8/3PN3/8/PPP2PPP/R1BQKBNR w KQkq - 1 5')

# %%
#5
board.push_san("Ng5") #Deep Blue
board.push_san("Ngf6") #Kasparov
board
# Out:
# Board('r1bqkb1r/pp1npppp/2p2n2/6N1/3P4/8/PPP2PPP/R1BQKBNR w KQkq - 3 6')

# %%
#6
board.push_san("Bd3") #Deep Blue
board.push_san("e6") #Kasparov
board
# Out:
# Board('r1bqkb1r/pp1n1ppp/2p1pn2/6N1/3P4/3B4/PPP2PPP/R1BQK1NR w KQkq - 0 7')

# %%
#7
board.push_san("N1f3") #Deep Blue
board.push_san("h6") #Kasparov
board
# Out:
# Board('r1bqkb1r/pp1n1pp1/2p1pn1p/6N1/3P4/3B1N2/PPP2PPP/R1BQK2R w KQkq - 0 8')

# %%
#8
board.push_san("Nxe6") #Deep Blue
board.push_san("Qe7") #Kasparov
board
# Out:
# Board('r1b1kb1r/pp1nqpp1/2p1Nn1p/8/3P4/3B1N2/PPP2PPP/R1BQK2R w KQkq - 1 9')

# %%
#9
board.push_san("Kh1") #Kasparov - castling
board.push_san("fxe6") #Kasparov
board
# Out:
# Board('r1b1kb1r/pp1nq1p1/2p1pn1p/8/3P4/3B1N2/PPP2PPP/R1BQ1RK1 w kq - 0 10')

# %%
#10
board.push_san("Bg6+") #Deep Blue
board.push_san("Kd8") #Kasparov
board
# Out:
# Board('r1bk1b1r/pp1nq1p1/2p1pnBp/8/3P4/5N2/PPP2PPP/R1BQ1RK1 w - - 2 11')

# %%
#11
board.push_san("Bf4") #Deep Blue
board.push_san("b5") #Kasparov
board
# Out:
# Board('r1bk1b1r/p2nq1p1/2p1pnBp/1p6/3P1B2/5N2/PPP2PPP/R2Q1RK1 w - - 0 12')

# %%
#12
board.push_san("a4") #Deep Blue
board.push_san("Bb7") #Kasparov
board
# Out:
# Board('r2k1b1r/pb1nq1p1/2p1pnBp/1p6/P2P1B2/5N2/1PP2PPP/R2Q1RK1 w - - 1 13')

# %%
#13
board.push_san("Re1") #Deep Blue
board.push_san("Nd5") #Kasparov
board
# Out:
# Board('r2k1b1r/pb1nq1p1/2p1p1Bp/1p1n4/P2P1B2/5N2/1PP2PPP/R2QR1K1 w - - 3 14')

# %%
#14
board.push_san("Bg3") #Deep Blue
board.push_san("Kc8") #Kasparov
board
# Out:
# Board('r1k2b1r/pb1nq1p1/2p1p1Bp/1p1n4/P2P4/5NB1/1PP2PPP/R2QR1K1 w - - 5 15')

# %%
#15
board.push_san("axb5") #Deep Blue
board.push_san("cxb5") #Kasparov
board
# Out:
# Board('r1k2b1r/pb1nq1p1/4p1Bp/1p1n4/3P4/5NB1/1PP2PPP/R2QR1K1 w - - 0 16')

# %%
#16
board.push_san("Qd3") #Deep Blue
board.push_san("Bc6") #Kasparov
board

# %%
#17
board.push_san("Bf5") #Deep Blue
board.push_san("exf5") #Kasparov
board

# %%
#18
board.push_san("Rxe7") #Deep Blue
board.push_san("Bxe7") #Kasparov
board

# %%
#19
board.push_san("c4") #Deep Blue
board

# %%
board.legal_moves

# %% [markdown]
#
# After 19th move, Kasparov resigned.
# *   {Rg8, Rf8, Re8, Rd8, Rh7} are all possible positions for the black rook in h8. {Rb8} is a potential move for the rook in a8. If the Black choses one of this moves, it will not effect the potential moves overall, since black rook will not threat any of the white pices. {Kb7,Kd8} are the potential moves for black king which does not effect the potential moves either. Hence this moves are not considered as "rational".
# *   Potential Moves for the black bishop in e7 are:
# Bf8, Bd8, Bf6, Bd6, Bg5, Bc5, Bh4, Bb4, Ba3
# *   Potential Moves for the black bishop in c6 ais:
# Bb7
# *   Potential Moves for the black knight in d7 are:
#  Nf8, Nb8, N7f6, N7b6, Ne5, Nc5
# *   Potential Moves for the black knight in d5 are:
# Nc7, N5f6, N5b6, Nf4, Nb4, Ne3, Nc3
#  * One of this moves of the black knight which is located in d5 is considered as the "best move" in this situation. (Nb4)

# %% [markdown]
# # **Why Stockfish 12?**
# http://rin.io/chess-engine/
#
# https://github.com/official-stockfish/Stockfish

# %% [markdown]
# https://nextchessmove.com/ is used to generate moves with Stockfish, GNU Chess, and LChess

# %% [markdown]
# For Kasparov's move
# * Stockfish 12 computed: b5c4
# * GNU Chess 6 computed: b5c4
# * LC0 0.26.3 computed: b5c4

# %%
#20 - Assumption
board.push_san("b5c4") #Kasparov
board
# Out:
# Board('r1k4r/p2nb1p1/2b4p/3n1p2/2pP4/3Q1NB1/1P3PPP/R5K1 w - - 0 20')

# %% [markdown]
# For deep-blue's move
# * Stockfish 12 computed: d3c4
# * GNU Chess 6 computed: d3c4
# * LC0 0.26.3 computed: d3f5 (another branch to be examine)

# %%
#20 - Assumption
board.push_san("Qc4") #Deep-Blue
board
# Out:
# Board('r1k4r/p2nb1p1/2b4p/3n1p2/2QP4/5NB1/1P3PPP/R5K1 b - - 0 20')

# %% [markdown]
# For Kasparov's move
# * Stockfish 12 computed: d5b4
# * GNU Chess 6 computed: d5b4
# * LC0 0.26.3 computed: d5b4

# %%
#21 - Assumption
board.push_san("Nb4") #Kasparov
board
# Out:
# Board('r1k4r/p2nb1p1/2b4p/5p2/1nQP4/5NB1/1P3PPP/R5K1 w - - 1 21')

# %% [markdown]
# For Deep-Blue's move
# * Stockfish 12 computed: a1e1
# * GNU Chess 6 computed: a1e1
# * LC0 0.26.3 computed: f3e5 (another brach to compute)

# %%
#21 - Assumption
board.push_san("Re1") #Deep-Blue
board
# Out:
# Board('r1k4r/p2nb1p1/2b4p/5p2/1nQP4/5NB1/1P3PPP/4R1K1 b - - 2 21')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: h8e8
# * GNU Chess 6 computed: h8e8
# * LC0 0.26.3 computed: c8d8

# %%
#22 - Assumption
board.push_san("Re8") #Kasparov
board
# Out:
# Board('r1k1r3/p2nb1p1/2b4p/5p2/1nQP4/5NB1/1P3PPP/4R1K1 w - - 3 22')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: e1e7
# * GNU Chess 6 computed: f3h4
# * LC0 0.26.3 computed: d4d5

# %%
#22 - Assumption - Stockfish 
board.push_san("Re7") #Deep Blue
board
# Out:
# Board('r1k1r3/p2nR1p1/2b4p/5p2/1nQP4/5NB1/1P3PPP/6K1 b - - 0 22')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: e8e7
# * GNU Chess 6 computed: e8e7
# * LC0 0.26.3 computed: e8e7

# %%
#23 - Assumption 
board.push_san("Re7") #Kasparov
board
# Out:
# Board('r1k5/p2nr1p1/2b4p/5p2/1nQP4/5NB1/1P3PPP/6K1 w - - 0 23')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: c4b4
# * GNU Chess 6 computed: c4b4
# * LC0 0.26.3 computed: c4b4

# %%
#23 - Assumption 
board.push_san("Qb4") #Deep-Blue
board
# Out:
# Board('r1k5/p2nr1p1/2b4p/5p2/1Q1P4/5NB1/1P3PPP/6K1 b - - 0 23')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: e7e4
# * GNU Chess 6 computed: c8d8
# * LC0 0.26.3 computed: c8d8

# %%
#24 - Assumption  - Stockfish
board.push_san("Re4") #Kasparov
board
# Out:
# Board('r1k5/p2n2p1/2b4p/5p2/1Q1Pr3/5NB1/1P3PPP/6K1 w - - 1 24')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: b4d6
# * GNU Chess 6 computed: b4d6
# * LC0 0.26.3 computed: f3e5

# %%
#24 - Assumption  - Stockfish
board.push_san("Qd6") #Deep Blue
board
# Out:
# Board('r1k5/p2n2p1/2bQ3p/5p2/3Pr3/5NB1/1P3PPP/6K1 b - - 2 24')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: c8d8
# * GNU Chess 6 computed: c8b7
# * LC0 0.26.3 computed: c8d8

# %%
#25 - Assumption  - Stockfish
board.push_san("Kd8") #Kasparov
board
# Out:
# Board('r2k4/p2n2p1/2bQ3p/5p2/3Pr3/5NB1/1P3PPP/6K1 w - - 3 25')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: d6c7
# * GNU Chess 6 computed: d6c7
# * LC0 0.26.3 computed: d6c7

# %%
#25 - Assumption  - Stockfish
board.push_san("Qc7") #Deep-Blue
board
# Out:
# Board('r2k4/p1Qn2p1/2b4p/5p2/3Pr3/5NB1/1P3PPP/6K1 b - - 4 25')

# %%
board.legal_moves
# Out:
# <LegalMoveGenerator at 0x7f97100356a0 (Ke8, Ke7)>

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: d8e7
# * GNU Chess 6 computed: d8e7
# * LC0 0.26.3 computed: d8e7

# %%
#26 - Assumption 
board.push_san("Ke7") #Kasparov
board
# Out:
# Board('r7/p1Qnk1p1/2b4p/5p2/3Pr3/5NB1/1P3PPP/6K1 w - - 5 26')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: c7c6
# * GNU Chess 6 computed: c7c6
# * LC0 0.26.3 computed: c7c6

# %%
#26 - Assumption 
board.push_san("Qc6") #Deep Blue
board
# Out:
# Board('r7/p2nk1p1/2Q4p/5p2/3Pr3/5NB1/1P3PPP/6K1 b - - 0 26')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: a8d8
# * GNU Chess 6 computed: d7b6
# * LC0 0.26.3 computed: a8f8

# %%
#27 - Assumption - Stockfish
board.push_san("Rd8") #Kasparov
board
# Out:
# Board('3r4/p2nk1p1/2Q4p/5p2/3Pr3/5NB1/1P3PPP/6K1 w - - 1 27')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: g3c7
# * GNU Chess 6 computed: g3c7
# * LC0 0.26.3 computed: h2h3

# %%
#27 - Assumption - Stockfish
board.push_san("Bc7") #Deep Blue
board
# Out:
# Board('3r4/p1Bnk1p1/2Q4p/5p2/3Pr3/5N2/1P3PPP/6K1 b - - 2 27')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: d7f6
# * GNU Chess 6 computed: d7f6
# * LC0 0.26.3 computed: e4e1

# %%
#28 - Assumption - Stockfish
board.push_san("Nf6") #Kasparov
board
# Out:
# Board('3r4/p1B1k1p1/2Q2n1p/5p2/3Pr3/5N2/1P3PPP/6K1 w - - 3 28')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: c6c5
# * GNU Chess 6 computed: c6c5
# * LC0 0.26.3 computed: c7d8

# %%
#28 - Assumption - Stockfish
board.push_san("Qc5") #Deep Blue
board
# Out:
# Board('3r4/p1B1k1p1/5n1p/2Q2p2/3Pr3/5N2/1P3PPP/6K1 b - - 4 28')

# %%
board.legal_moves
# Out:
# <LegalMoveGenerator at 0x7f97100356a0 (Ke8, Kf7, Kd7, Ke6, Rd6)>

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: e7e8
# * GNU Chess 6 computed: e7e8
# * LC0 0.26.3 computed: e7d7

# %%
#29 - Assumption - Stockfish
board.push_san("Ke8") #Kasparov
board
# Out:
# Board('3rk3/p1B3p1/5n1p/2Q2p2/3Pr3/5N2/1P3PPP/6K1 w - - 5 29')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: c7d8
# * GNU Chess 6 computed: c7d8
# * LC0 0.26.3 computed: h2h3

# %%
#29 - Assumption - Stockfish
board.push_san("Bd8") #Deep Blue
board
# Out:
# Board('3Bk3/p5p1/5n1p/2Q2p2/3Pr3/5N2/1P3PPP/6K1 b - - 0 29')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: e8d8
# * GNU Chess 6 computed: e8d8
# * LC0 0.26.3 computed: e8d8

# %%
#30 - Assumption 
board.push_san("Kd8") #Kasparov
board
# Out:
# Board('3k4/p5p1/5n1p/2Q2p2/3Pr3/5N2/1P3PPP/6K1 w - - 0 30')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: c5a7
# * GNU Chess 6 computed: c5a7
# * LC0 0.26.3 computed: h2h3

# %%
#30 - Assumption - Stockfish
board.push_san("Qa7") #Deep Blue
board
# Out:
# Board('3k4/Q5p1/5n1p/5p2/3Pr3/5N2/1P3PPP/6K1 b - - 0 30')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: h6h5
# * GNU Chess 6 computed: f6d7
# * LC0 0.26.3 computed: e4e1

# %%
#31 - Assumption - Stockfish
board.push_san("h5") #Kasparov
board
# Out:
# Board('3k4/Q5p1/5n2/5p1p/3Pr3/5N2/1P3PPP/6K1 w - - 0 31')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: a7g7
# * GNU Chess 6 computed: a7g7
# * LC0 0.26.3 computed: a7g8

# %%
#31 - Assumption - Stockfish
board.push_san("Qg7") #Deep Blue
board
# Out:
# Board('3k4/6Q1/5n2/5p1p/3Pr3/5N2/1P3PPP/6K1 b - - 0 31')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: e4e6
# * GNU Chess 6 computed: e4e6
# * LC0 0.26.3 computed: f6e8

# %%
#32 - Assumption - Stockfish
board.push_san("Re6") #Kasparov
board
# Out:
# Board('3k4/6Q1/4rn2/5p1p/3P4/5N2/1P3PPP/6K1 w - - 1 32')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: g7f8
# * GNU Chess 6 computed: g7f8
# * LC0 0.26.3 computed: g7f8

# %%
#32 - Assumption
board.push_san("Qf8") #Deep Blue
board
# Out:
# Board('3k1Q2/8/4rn2/5p1p/3P4/5N2/1P3PPP/6K1 b - - 2 32')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: f6e8
# * GNU Chess 6 computed: f6e8
# * LC0 0.26.3 computed: f6e8

# %%
#33 - Assumption 
board.push_san("Ne8") #Kasparov
board
# Out:
# Board('3knQ2/8/4r3/5p1p/3P4/5N2/1P3PPP/6K1 w - - 3 33')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: f3e5
# * GNU Chess 6 computed: f8e5
# * LC0 0.26.3 computed: f8e5

# %%
#33 - Assumption
board.push_san("Ne5") #Deep Blue
board
# Out:
# Board('3knQ2/8/4r3/4Np1p/3P4/8/1P3PPP/6K1 b - - 4 33')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: e6d6
# * GNU Chess 6 computed: e6a6
# * LC0 0.26.3 computed: e6f6

# %% [markdown]
# ~~My note: LC0 may be the best choice but will move with stockfish for now~~

# %%
#34 - Assumption - Stockfish
board.push_san("Rd6") #Kasparov
board
# Out:
# Board('3knQ2/8/3r4/4Np1p/3P4/8/1P3PPP/6K1 w - - 5 34')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: e5f7
# * GNU Chess 6 computed: f8f5
# * LC0 0.26.3 computed: e5f7

# %%
#34 - Assumption
board.push_san("Nf7") #Deep Blue
board
# Out:
# Board('3knQ2/5N2/3r4/5p1p/3P4/8/1P3PPP/6K1 b - - 6 34')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: d8d7
# * GNU Chess 6 computed: d8d7
# * LC0 0.26.3 computed: d8c7

# %%
#35 - Assumption - Stockfish
board.push_san("Kd7") #Kasparov
board
# Out:
# Board('4nQ2/3k1N2/3r4/5p1p/3P4/8/1P3PPP/6K1 w - - 7 35')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: f7d6
# * GNU Chess 6 computed: f7d6
# * LC0 0.26.3 computed: h2h3

# %%
#35 - Assumption
board.push_san("Nd6") #Deep Blue
board
# Out:
# Board('4nQ2/3k4/3N4/5p1p/3P4/8/1P3PPP/6K1 b - - 0 35')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: e8d6
# * GNU Chess 6 computed: e8d6
# * LC0 0.26.3 computed: e8d6

# %%
#36 - Assumption - Stockfish
board.push_san("Nd6") #Kasparov
board
# Out:
# Board('5Q2/3k4/3n4/5p1p/3P4/8/1P3PPP/6K1 w - - 0 36')

# %% [markdown]
# For Deep-Blue's move
#
# * Stockfish 12 computed: f8d6
# * GNU Chess 6 computed: d4d5
# * LC0 0.26.3 computed: f8g8

# %%
#36 - Assumption
board.push_san("Qd6") #Deep Blue
board
# Out:
# Board('8/3k4/3Q4/5p1p/3P4/8/1P3PPP/6K1 b - - 0 36')

# %% [markdown]
# For Kasparov's move
#
# * Stockfish 12 computed: d7d6
# * GNU Chess 6 computed: d7d6
# * LC0 0.26.3 computed: d7d6

# %%
#37 - Assumption 
board.push_san("Kd6") #Kasparov
board
# Out:
# Board('8/8/3k4/5p1p/3P4/8/1P3PPP/6K1 w - - 0 37')
