# %%
import chess
board = chess.Board()
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
#1
board.push_san("e4") #Deep Blue
board.push_san("c6") #Kasparov
board
# Out:
# Board('rnbqkbnr/pp1ppppp/2p5/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2')

# %%
#2
board.push_san("d4") #Deep Blue
board.push_san("d5") #Kasparov
board
# Out:
# Board('rnbqkbnr/pp2pppp/2p5/3p4/3PP3/8/PPP2PPP/RNBQKBNR w KQkq - 0 3')

# %%
#3 
board.push_san("Nc3") #Deep Blue
board.push_san("dxe4") #Kasparov
board
# Out:
# Board('rnbqkbnr/pp2pppp/2p5/8/3Pp3/2N5/PPP2PPP/R1BQKBNR w KQkq - 0 4')

# %%
#4
board.push_san("Nxe4") #Deep Blue
board.push_san("Nd7") #Kasparov
board
# Out:
# Board('r1bqkbnr/pp1npppp/2p5/8/3PN3/8/PPP2PPP/R1BQKBNR w KQkq - 1 5')

# %%
#5
board.push_san("Ng5") #Deep Blue
board.push_san("Ngf6") #Kasparov
board
# Out:
# Board('r1bqkb1r/pp1npppp/2p2n2/6N1/3P4/8/PPP2PPP/R1BQKBNR w KQkq - 3 6')

# %%
#6
board.push_san("Bd3") #Deep Blue
board.push_san("e6") #Kasparov
board
# Out:
# Board('r1bqkb1r/pp1n1ppp/2p1pn2/6N1/3P4/3B4/PPP2PPP/R1BQK1NR w KQkq - 0 7')

# %%
#7
board.push_san("N1f3") #Deep Blue
board
# Out:
# Board('r1bqkb1r/pp1n1ppp/2p1pn2/6N1/3P4/3B1N2/PPP2PPP/R1BQK2R b KQkq - 1 7')

# %%
board.fen() #to get current state of the chessboard 
#to perform the Stockfish chess engine analysis
# Out:
# 'r1bqkb1r/pp1n1ppp/2p1pn2/6N1/3P4/3B1N2/PPP2PPP/R1BQK2R b KQkq - 1 7'

# %%
#7 - Stockfish Result
board.push_san("Bd6") #Kasparov while Kasparov played pawn at h7 to h6 in real life
board
# Out:
# Board('r1bqk2r/pp1n1ppp/2pbpn2/6N1/3P4/3B1N2/PPP2PPP/R1BQK2R w KQkq - 2 8')

# %%
#8
board.push_san("Qe2") #Deep Blue
board
# Out:
# Board('r1bqk2r/pp1n1ppp/2pbpn2/6N1/3P4/3B1N2/PPP1QPPP/R1B1K2R b KQkq - 3 8')

# %%
#8
board.push_san("h6") #Kasparov (this move was the Kasparov's 7th move in real life)
board
# Out:
# Board('r1bqk2r/pp1n1pp1/2pbpn1p/6N1/3P4/3B1N2/PPP1QPPP/R1B1K2R w KQkq - 0 9')

# %%
#9
board.push_san("Ne4") #Deep Blue
board
# Out:
# Board('r1bqk2r/pp1n1pp1/2pbpn1p/8/3PN3/3B1N2/PPP1QPPP/R1B1K2R b KQkq - 1 9')

# %%
#9
board.push_san("Ne4") #Kasparov
board
# Out:
# Board('r1bqk2r/pp1n1pp1/2pbp2p/8/3Pn3/3B1N2/PPP1QPPP/R1B1K2R w KQkq - 0 10')

# %%
#10
board.push_san("Qe4") #Deep Blue
board
# Out:
# Board('r1bqk2r/pp1n1pp1/2pbp2p/8/3PQ3/3B1N2/PPP2PPP/R1B1K2R b KQkq - 0 10')

# %%
#10
board.push_san("c5") #Kasparov
board
# Out:
# Board('r1bqk2r/pp1n1pp1/3bp2p/2p5/3PQ3/3B1N2/PPP2PPP/R1B1K2R w KQkq - 0 11')

# %%
#11
board.push_san("Qg4") #Deep Blue
board
# Out:
# Board('r1bqk2r/pp1n1pp1/3bp2p/2p5/3P2Q1/3B1N2/PPP2PPP/R1B1K2R b KQkq - 1 11')

# %%
#11
board.push_san("Qf6") #Kasparov
board
# Out:
# Board('r1b1k2r/pp1n1pp1/3bpq1p/2p5/3P2Q1/3B1N2/PPP2PPP/R1B1K2R w KQkq - 2 12')

# %%
#12
board.push_san("Be3") #Deep Blue
board
# Out:
# Board('r1b1k2r/pp1n1pp1/3bpq1p/2p5/3P2Q1/3BBN2/PPP2PPP/R3K2R b KQkq - 3 12')

# %%
#12
board.push_san("d4") #Kasparov
board
# Out:
# Board('r1b1k2r/pp1n1pp1/3bpq1p/8/3p2Q1/3BBN2/PPP2PPP/R3K2R w KQkq - 0 13')

# %%
#13
board.push_san("Bd4") #Deep Blue
board
# Out:
# Board('r1b1k2r/pp1n1pp1/3bpq1p/8/3B2Q1/3B1N2/PPP2PPP/R3K2R b KQkq - 0 13')

# %%
#13
board.push_san("e5") #Kasparov
board
# Out:
# Board('r1b1k2r/pp1n1pp1/3b1q1p/4p3/3B2Q1/3B1N2/PPP2PPP/R3K2R w KQkq - 0 14')

# %%
#14
board.push_san("Qe4") #Deep Blue
board
# Out:
# Board('r1b1k2r/pp1n1pp1/3b1q1p/4p3/3BQ3/3B1N2/PPP2PPP/R3K2R b KQkq - 1 14')

# %%
#14
board.push_san("Qe7") #Kasparov
board
# Out:
# Board('r1b1k2r/pp1nqpp1/3b3p/4p3/3BQ3/3B1N2/PPP2PPP/R3K2R w KQkq - 2 15')

# %%
#15
board.push_san("Bc3") #Deep Blue
board
# Out:
# Board('r1b1k2r/pp1nqpp1/3b3p/4p3/4Q3/2BB1N2/PPP2PPP/R3K2R b KQkq - 3 15')

# %%
#15
board.push_san("Nc5") #Kasparov
board
# Out:
# Board('r1b1k2r/pp2qpp1/3b3p/2n1p3/4Q3/2BB1N2/PPP2PPP/R3K2R w KQkq - 4 16')

# %%
#16
board.push_san("Bb5") #Deep Blue
board
# Out:
# Board('r1b1k2r/pp2qpp1/3b3p/1Bn1p3/4Q3/2B2N2/PPP2PPP/R3K2R b KQkq - 5 16')

# %%
#16
board.push_san("Bd7") #Kasparov
board
# Out:
# Board('r3k2r/pp1bqpp1/3b3p/1Bn1p3/4Q3/2B2N2/PPP2PPP/R3K2R w KQkq - 6 17')

# %%
#17
board.push_san("Bd7") #Deep Blue
board
# Out:
# Board('r3k2r/pp1Bqpp1/3b3p/2n1p3/4Q3/2B2N2/PPP2PPP/R3K2R b KQkq - 0 17')

# %%
#17
board.push_san("Qd7") #Kasparov
board
# Out:
# Board('r3k2r/pp1q1pp1/3b3p/2n1p3/4Q3/2B2N2/PPP2PPP/R3K2R w KQkq - 0 18')

# %%
#18
board.push_san("Qc4") #Deep Blue
board
# Out:
# Board('r3k2r/pp1q1pp1/3b3p/2n1p3/2Q5/2B2N2/PPP2PPP/R3K2R b KQkq - 1 18')

# %%
#18
board.push_san("e4") #Kasparov
board
# Out:
# Board('r3k2r/pp1q1pp1/3b3p/2n5/2Q1p3/2B2N2/PPP2PPP/R3K2R w KQkq - 0 19')

# %%
#19
board.push_san("Ne5") #Deep Blue
board
# Out:
# Board('r3k2r/pp1q1pp1/3b3p/2n1N3/2Q1p3/2B5/PPP2PPP/R3K2R b KQkq - 1 19')

# %%
#19
board.push_san("Be5") #Kasparov
board
# Out:
# Board('r3k2r/pp1q1pp1/7p/2n1b3/2Q1p3/2B5/PPP2PPP/R3K2R w KQkq - 0 20')

# %%
#20
board.push_san("Qc5") #Deep Blue
board
# Out:
# Board('r3k2r/pp1q1pp1/7p/2Q1b3/4p3/2B5/PPP2PPP/R3K2R b KQkq - 0 20')

# %%
#20
board.push_san("Bc3") #Kasparov
board
# Out:
# Board('r3k2r/pp1q1pp1/7p/2Q5/4p3/2b5/PPP2PPP/R3K2R w KQkq - 0 21')

# %%
#21
board.push_san("c3") #Deep Blue
board
# Out:
# Board('r3k2r/pp1q1pp1/7p/2Q5/4p3/2P5/P1P2PPP/R3K2R b KQkq - 0 21')

# %%
#21
board.push_san("b6") #Kasparov
board
# Out:
# Board('r3k2r/p2q1pp1/1p5p/2Q5/4p3/2P5/P1P2PPP/R3K2R w KQkq - 0 22')

# %%
#22
board.push_san("Qe5") #Deep Blue
board
# Out:
# Board('r3k2r/p2q1pp1/1p5p/4Q3/4p3/2P5/P1P2PPP/R3K2R b KQkq - 1 22')

# %%
#22
board.push_san("Kf8") #Kasparov
board
# Out:
# Board('r4k1r/p2q1pp1/1p5p/4Q3/4p3/2P5/P1P2PPP/R3K2R w KQ - 2 23')

# %%
#23
board.push_san("Rd1") #Deep Blue
board
# Out:
# Board('r4k1r/p2q1pp1/1p5p/4Q3/4p3/2P5/P1P2PPP/3RK2R b K - 3 23')

# %%
#23
board.push_san("Qe7") #Kasparov
board
# Out:
# Board('r4k1r/p3qpp1/1p5p/4Q3/4p3/2P5/P1P2PPP/3RK2R w K - 4 24')

# %%
#24
board.push_san("Qd5") #Deep Blue
board
# Out:
# Board('r4k1r/p3qpp1/1p5p/3Q4/4p3/2P5/P1P2PPP/3RK2R b K - 5 24')

# %%
#24
board.push_san("Re8") #Kasparov
board
# Out:
# Board('4rk1r/p3qpp1/1p5p/3Q4/4p3/2P5/P1P2PPP/3RK2R w K - 6 25')

# %%
#25
board.push_san("Kh1") #Deep Blue
board
# Out:
# Board('4rk1r/p3qpp1/1p5p/3Q4/4p3/2P5/P1P2PPP/3R1RK1 b - - 7 25')

# %%
#25
board.push_san("g5") #Kasparov
board
# Out:
# Board('4rk1r/p3qp2/1p5p/3Q2p1/4p3/2P5/P1P2PPP/3R1RK1 w - - 0 26')

# %%
#26
board.push_san("Qd4") #Deep Blue
board
# Out:
# Board('4rk1r/p3qp2/1p5p/6p1/3Qp3/2P5/P1P2PPP/3R1RK1 b - - 1 26')

# %%
#26
board.push_san("Rh7") #Kasparov
board
# Out:
# Board('4rk2/p3qp1r/1p5p/6p1/3Qp3/2P5/P1P2PPP/3R1RK1 w - - 2 27')

# %%
#27
board.push_san("Qa4") #Deep Blue
board
# Out:
# Board('4rk2/p3qp1r/1p5p/6p1/Q3p3/2P5/P1P2PPP/3R1RK1 b - - 3 27')

# %%
#27
board.push_san("f6") #Kasparov
board
# Out:
# Board('4rk2/p3q2r/1p3p1p/6p1/Q3p3/2P5/P1P2PPP/3R1RK1 w - - 0 28')

# %%
#28
board.push_san("Rf1e1") #Deep Blue
board
# Out:
# Board('4rk2/p3q2r/1p3p1p/6p1/Q3p3/2P5/P1P2PPP/3RR1K1 b - - 1 28')

# %%
#28
board.push_san("Rf7") #Kasparov
board
# Out:
# Board('4rk2/p3qr2/1p3p1p/6p1/Q3p3/2P5/P1P2PPP/3RR1K1 w - - 2 29')

# %%
#29
board.push_san("Rd5") #Deep Blue
board
# Out:
# Board('4rk2/p3qr2/1p3p1p/3R2p1/Q3p3/2P5/P1P2PPP/4R1K1 b - - 3 29')

# %%
#29
board.push_san("f5") #Kasparov
board
# Out:
# Board('4rk2/p3qr2/1p5p/3R1pp1/Q3p3/2P5/P1P2PPP/4R1K1 w - - 0 30')

# %%
#30
board.push_san("Qc6") #Deep Blue
board
# Out:
# Board('4rk2/p3qr2/1pQ4p/3R1pp1/4p3/2P5/P1P2PPP/4R1K1 b - - 1 30')

# %%
#30
board.push_san("Rf6") #Kasparov
board
# Out:
# Board('4rk2/p3q3/1pQ2r1p/3R1pp1/4p3/2P5/P1P2PPP/4R1K1 w - - 2 31')

# %%
#31
board.push_san("Qa4") #Deep Blue
board
# Out:
# Board('4rk2/p3q3/1p3r1p/3R1pp1/Q3p3/2P5/P1P2PPP/4R1K1 b - - 3 31')

# %%
#31
board.push_san("Qe6") #Kasparov
board
# Out:
# Board('4rk2/p7/1p2qr1p/3R1pp1/Q3p3/2P5/P1P2PPP/4R1K1 w - - 4 32')

# %%
#32
board.push_san("Qd4") #Deep Blue
board
# Out:
# Board('4rk2/p7/1p2qr1p/3R1pp1/3Qp3/2P5/P1P2PPP/4R1K1 b - - 5 32')

# %%
#32
board.push_san("Re7") #Kasparov
board
# Out:
# Board('5k2/p3r3/1p2qr1p/3R1pp1/3Qp3/2P5/P1P2PPP/4R1K1 w - - 6 33')

# %%
#33
board.push_san("Re3") #Deep Blue
board
# Out:
# Board('5k2/p3r3/1p2qr1p/3R1pp1/3Qp3/2P1R3/P1P2PPP/6K1 b - - 7 33')

# %%
#33
board.push_san("Kg7") #Kasparov
board
# Out:
# Board('8/p3r1k1/1p2qr1p/3R1pp1/3Qp3/2P1R3/P1P2PPP/6K1 w - - 8 34')

# %%
#34
board.push_san("f3") #Deep Blue
board
# Out:
# Board('8/p3r1k1/1p2qr1p/3R1pp1/3Qp3/2P1RP2/P1P3PP/6K1 b - - 0 34')

# %%
#34
board.push_san("g4") #Kasparov
board
# Out:
# Board('8/p3r1k1/1p2qr1p/3R1p2/3Qp1p1/2P1RP2/P1P3PP/6K1 w - - 0 35')

# %%
#35
board.push_san("g4") #Deep Blue
board
# Out:
# Board('8/p3r1k1/1p2qr1p/3R1p2/3Qp1P1/2P1R3/P1P3PP/6K1 b - - 0 35')

# %%
#35
board.push_san("g4") #Kasparov
board
# Out:
# Board('8/p3r1k1/1p2qr1p/3R4/3Qp1p1/2P1R3/P1P3PP/6K1 w - - 0 36')

# %%
#36
board.push_san("a4") #Deep Blue
board
# Out:
# Board('8/p3r1k1/1p2qr1p/3R4/P2Qp1p1/2P1R3/2P3PP/6K1 b - - 0 36')

# %%
#36
board.push_san("a5") #Kasparov
board
# Out:
# Board('8/4r1k1/1p2qr1p/p2R4/P2Qp1p1/2P1R3/2P3PP/6K1 w - - 0 37')

# %%
#37
board.push_san("c4") #Deep Blue
board
# Out:
# Board('8/4r1k1/1p2qr1p/p2R4/P1PQp1p1/4R3/2P3PP/6K1 b - - 0 37')

# %%
#37
board.push_san("Kh7") #Kasparov
board
# Out:
# Board('8/4r2k/1p2qr1p/p2R4/P1PQp1p1/4R3/2P3PP/6K1 w - - 1 38')

# %%
#38
board.push_san("c3") #Deep Blue
board
# Out:
# Board('8/4r2k/1p2qr1p/p2R4/P1PQp1p1/2P1R3/6PP/6K1 b - - 0 38')

# %%
#38
board.push_san("Qf7") #Kasparov
board
# Out:
# Board('8/4rq1k/1p3r1p/p2R4/P1PQp1p1/2P1R3/6PP/6K1 w - - 1 39')

# %%
#39
board.push_san("Qd1") #Deep Blue
board
# Out:
# Board('8/4rq1k/1p3r1p/p2R4/P1P1p1p1/2P1R3/6PP/3Q2K1 b - - 2 39')

# %%
#39
board.push_san("Qe6") #Kasparov
board
# Out:
# Board('8/4r2k/1p2qr1p/p2R4/P1P1p1p1/2P1R3/6PP/3Q2K1 w - - 3 40')

# %%
#40
board.push_san("Qd4") #Deep Blue
board
# Out:
# Board('8/4r2k/1p2qr1p/p2R4/P1PQp1p1/2P1R3/6PP/6K1 b - - 4 40')

# %%
#40
board.push_san("Qf7") #Kasparov
board
# Out:
# Board('8/4rq1k/1p3r1p/p2R4/P1PQp1p1/2P1R3/6PP/6K1 w - - 5 41')

# %%
#41 - looping
board.push_san("Qd1") #Deep Blue
board
# Out:
# Board('8/4rq1k/1p3r1p/p2R4/P1P1p1p1/2P1R3/6PP/3Q2K1 b - - 6 41')

# %%
#41
board.push_san("Qe6") #Kasparov
board
# Out:
# Board('8/4r2k/1p2qr1p/p2R4/P1P1p1p1/2P1R3/6PP/3Q2K1 w - - 7 42')
